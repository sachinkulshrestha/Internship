# %%
pip install selenium

# %%
import selenium 
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
driver= webdriver.Chrome(r'C:/Users/dell/Downloads/chromedriver_win32/chromedriver.exe')

# %% [markdown]
# # Question 1

# %%
 driver=webdriver.Chrome('chromedriver.exe')

# %%
url='https://www.naukri.com/'
driver.get(url)

# %%
search_job=driver.find_element_by_class_name('suggestor-input')
search_job

# %%
search_job.send_keys('Data Analyst')

# %%
search_loc=driver.find_element_by_xpath('/html/body/div/div[2]/div[3]/div/div/div[3]/div/div/div/input')
search_loc

# %%
search_loc.send_keys('Bangalore')

# %%
search_btn=driver.find_element_by_xpath('/html/body/div/div[2]/div[3]/div/div/div[6]')
search_btn

# %%
search_btn.click()

# %%
jobs=driver.find_elements_by_xpath('//article[@class="jobTuple bgWhite br4 mb-8"]')
len(jobs)
jobs[0:9]

# %%
job=[]
for i in jobs:
    job.append(i.text.replace('\n',''))
job

# %%
len(job)

# %%
job_title=driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')

job_title

# %%
jobs_titl=[]
for i in job_title:
    jobs_titl.append(i.text)
jobs_title=jobs_titl[0:10]
jobs_title

# %%
len(jobs_title)

# %%
job_loc=driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi location"]')

job_loc

# %%
jobs_loc=[]
for i in job_loc:
    jobs_loc.append(i.text)
jobs_locn=jobs_loc[0:10]
jobs_locn

# %%
company=driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')
company

# %%
companys=[]
for i in company:
    companys.append(i.text.replace('\n',''))
job_company=companys[0:10]
job_company

# %%
exp=driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi experience"]')
exp

# %%
experience_required=[]
for i in exp:
    experience_required.append(i.text)
experience_requireds=experience_required[0:10]
experience_requireds

# %%
datas=list(zip(jobs_title,jobs_locn,job_company,experience_requireds))

# %%
df=pd.DataFrame(datas,columns=['Job-title','Job-location','Company_name','Experience_required'])

# %%
df
# Out:
#                                            Job-title  \
# 0            Hiring For Data Analyst I(SQL & Python)
# 1                   Data Analyst - 3rd Party Payroll
# 2                                     Data Analyst I
# 3                             Senior Data Analyst II
# 4                                Senior Data Analyst
# 5                             Senior Data Analyst II
# 6                             Senior Data Analyst II
# 7          Looking For Data Analyst - Remote Support
# 8                Job openings For Data Analyst - AOA
# 9  Senior Data Analyst - Ads & Promotion Platform...
#
#                                         Job-location  \
# 0                                Bangalore/Bengaluru
# 1                                Bangalore/Bengaluru
# 2                                Bangalore/Bengaluru
# 3                                Bangalore/Bengaluru
# 4                                Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# ...

# %% [markdown]
# # Question 2

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get('https://www.naukri.com/')
driver.find_element_by_class_name('suggestor-input').send_keys('Data Scientist')
driver.find_element_by_xpath('/html/body/div/div[2]/div[3]/div/div/div[3]/div/div/div/input').send_keys('Bangalore')
driver.find_element_by_class_name('qsbSubmit').click()

# %%
job_title=[]
job_loctation=[]
company_name=[]
for t in driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]'):
    job_title.append(t.text)
for l in driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi location"]'):
    job_loctation.append(l.text)
for n in driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]'):
    company_name.append(n.text)
    
Data_Scientist_jobs=pd.DataFrame({})
Data_Scientist_jobs['Job_title']=job_title[0:10]
Data_Scientist_jobs['Job_loctation']=job_loctation[0:10]
Data_Scientist_jobs['company_name']=company_name[0:10]

Data_Scientist_jobs
# Out:
#                                            Job_title  \
# 0                                 Data Scientist III
# 1                                  Sr Data Scientist
# 2      Data Scientist/Senior Data Scientist - Python
# 3             HCL Tech Opening - Lead Data Scientist
# 4                                Sr . Data Scientist
# 5  Need Data scientists and data engineers - WFH-...
# 6  Sr. Data Scientist - Manufacturing Projects - ...
# 7                           Principal Data Scientist
# 8                                     Data Scientist
# 9                                     Data Scientist
#
#                                        Job_loctation  \
# 0                                Bangalore/Bengaluru
# 1                                Bangalore/Bengaluru
# 2                                Bangalore/Bengaluru
# 3  Kolkata, Hyderabad/Secunderabad, Pune, Chennai...
# 4                                Bangalore/Bengaluru
# 5  Hyderabad/Secunderabad, Bangalore/Bengaluru, M...
# ...

# %% [markdown]
# # Question 3

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get('https://www.naukri.com/')
driver.find_element_by_class_name('suggestor-input').send_keys('Data Scientist')
driver.find_element_by_class_name('qsbSubmit').click()

# %%
driver.find_element_by_xpath('/html/body/div/div[3]/div[2]/section[1]/div[2]/div[3]/div[2]/div[3]/label/i').click()

# %%
driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[4]/div[2]/div[2]/label/i').click()

# %%
title=[]
location=[]
company=[]
experience=[]
for t in driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]'):
    title.append(t.text)
for l in driver.find_elements_by_xpath('//span[@class="ellipsis fleft fs12 lh16 halfwdt"]'):
    location.append(l.text)
for c in driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]'):
    company.append(c.text)
for e in driver.find_elements_by_xpath('//span[@class="ellipsis fleft fs12 lh16 expwdth"]'):
    experience.append(e.text)

# %%
Data_Scientist_delhi=pd.DataFrame({})
Data_Scientist_delhi['Job_title']=title[0:5]
Data_Scientist_delhi['Job_loctation']=location[0:5]
Data_Scientist_delhi['company_name']=company[0:5]
Data_Scientist_delhi['experience required']=experience[0:5]
Data_Scientist_delhi
# Out:
#                                            Job_title  \
# 0  Excellent Opportunity For Freshers For AI/ML, ...
# 1  Data Analyst / Data Scientist / Business Analy...
# 2             Hiring For Senior Data Scientist-Noida
# 3                             Data scientist- Python
# 4                                Data Scientist _NLP
#
#                                        Job_loctation  \
# 0  Noida, Kolkata, Hyderabad/Secunderabad, Pune, ...
# 1                   Bangalore/Bengaluru, Delhi / NCR
# 2                                        Delhi / NCR
# 3  Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...
# 4  Noida, New Delhi, Bangalore Rural, Bangalore/B...
#
#                          company_name experience required
# 0                            NTT Data             0-0 Yrs
# 1           GABA Consultancy services             3-8 Yrs
# 2                            Lumiq.ai             2-4 Yrs
# 3  TeamPlus Staffing Solution Pvt Ltd             0-3 Yrs
# ...

# %% [markdown]
# # Question 4

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get('https://www.flipkart.com/')

# %%
driver.find_element_by_class_name('_3704LK').send_keys('sunglasses')

# %%
driver.find_element_by_xpath('/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button').click()

# %%
brand=[]
product=[]
price=[]
for b in driver.find_elements_by_xpath('//div[@class="_2WkVRV"]'):
    brand.append(b.text)
for p in driver.find_elements_by_xpath('//a[@class="IRpwTa"]'):
    product.append(p.text)
for pi in driver.find_elements_by_xpath('//div[@class="_30jeq3"]'):
    price.append(pi.text)

# %%
driver.find_element_by_class_name('_1LKTO3').click()

# %%
brand_1=[]
product_1=[]
price_1=[]
for b in driver.find_elements_by_xpath('//div[@class="_2WkVRV"]'):
    brand_1.append(b.text)
for p in driver.find_elements_by_xpath('//a[@class="IRpwTa"]'):
    product_1.append(p.text)
for pi in driver.find_elements_by_xpath('//div[@class="_30jeq3"]'):
    price_1.append(pi.text)

# %%
driver.find_element_by_xpath('/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[12]/span').click()

# %%
brand_2=[]
product_2=[]
price_2=[]
for b in driver.find_elements_by_xpath('//div[@class="_2WkVRV"]'):
    brand_2.append(b.text)
for p in driver.find_elements_by_xpath('//a[@class="IRpwTa"]'):
    product_2.append(p.text)
for pi in driver.find_elements_by_xpath('//div[@class="_30jeq3"]'):
    price_2.append(pi.text)

# %%
brand_=brand_2[0:20]
product_=product_2[0:20]
price_=price_2[0:20]

# %%
brand.extend(brand_1)

# %%
brand.extend(brand_)

# %%
len(brand)
# Out:
# 100

# %%
product.extend(product_1)
product.extend(product_)
len(product)
# Out:
# 100

# %%
price.extend(price_1)
price.extend(price_)
len(price)
# Out:
# 100

# %%
sunglasses=pd.DataFrame({})
sunglasses['Brand']=brand
sunglasses['Product']=product
sunglasses['Price']=price
sunglasses
# Out:
#              Brand                                            Product   Price
# 0    VINCENT CHASE             UV Protection Wayfarer Sunglasses (55)    ₹949
# 1    VINCENT CHASE  by Lenskart Polarized, UV Protection Round Sun...  ₹1,344
# 2             SRPM             UV Protection Wayfarer Sunglasses (50)    ₹198
# 3           SUNBEE  UV Protection, Polarized Wayfarer Sunglasses (...    ₹253
# 4        Elligator                UV Protection Round Sunglasses (54)    ₹258
# ..             ...                                                ...     ...
# 95    LOUIS KOUROS              UV Protection Aviator Sunglasses (60)  ₹1,349
# 96          PIRASO                   Mirrored Aviator Sunglasses (32)    ₹199
# 97       ROYAL SON                   Mirrored Aviator Sunglasses (55)    ₹379
# 98        Fastrack      Polarized Retro Square Sunglasses (Free Size)    ₹639
# 99  ROZZETTA CRAFT              UV Protection Aviator Sunglasses (62)    ₹616
#
# [100 rows x 3 columns]

# %% [markdown]
# # Question 6

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get('https://www.flipkart.com')

# %%
driver.find_element_by_class_name('_3704LK').send_keys('sneakers')

# %%
driver.find_element_by_xpath('/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button').click()

# %%
brand=[]
product=[]
productm=[]
discount=[]
price=[]
for b in driver.find_elements_by_xpath('//div[@class="_2WkVRV"]'):
    brand.append(b.text)
for p in driver.find_elements_by_xpath('//a[@class="IRpwTa"]'):
    product.append(p.text)
for d in driver.find_elements_by_xpath('//div[@class="_3Ay6Sb"]'):
    discount.append(d.text)
for pi in driver.find_elements_by_xpath('//div[@class="_30jeq3"]'):
    price.append(pi.text)
for mb in driver.find_elements_by_xpath('//a[@class="IRpwTa _2-ICcC"]'):
    productm.append(mb.text)

# %%
driver.find_element_by_class_name('_1LKTO3').click()

# %%
brand_1=[]
product_1=[]
discount_1=[]
price_1=[]
productm_1=[]
for b in driver.find_elements_by_xpath('//div[@class="_2WkVRV"]'):
    brand_1.append(b.text)
for p in driver.find_elements_by_xpath('//a[@class="IRpwTa"]'):
    product_1.append(p.text)
for d in driver.find_elements_by_xpath('//div[@class="_3Ay6Sb"]'):
    discount_1.append(d.text)
for pi in driver.find_elements_by_xpath('//div[@class="_30jeq3"]'):
    price_1.append(pi.text)
for mb in driver.find_elements_by_xpath('//a[@class="IRpwTa _2-ICcC"]'):
    productm_1.append(mb.text)

# %%
driver.find_element_by_xpath('/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[12]/span').click()

# %%
brand_2=[]
product_2=[]
discount_2=[]
price_2=[]
for b in driver.find_elements_by_xpath('//div[@class="_2WkVRV"]'):
    brand_2.append(b.text)
for p in driver.find_elements_by_xpath('//a[@class="IRpwTa"]'):
    product_2.append(p.text)
for d in driver.find_elements_by_xpath('//div[@class="_3Ay6Sb"]'):
    discount_2.append(d.text)
for pi in driver.find_elements_by_xpath('//div[@class="_30jeq3"]'):
    price_2.append(pi.text)

# %%
brand_=brand_2[0:20]
product_=product_2[0:20]
discount_=discount_2[0:20]
price_=price_2[0:20]

# %%
brand.extend(brand_1)
brand.extend(brand_)
product.extend(productm)
product.extend(product_1)
product.extend(productm_1)
product.extend(product_)
discount.extend(discount_1)
discount.extend(discount_)
price.extend(price_1)
price.extend(price_)

# %%
sneakers=pd.DataFrame({})
sneakers['Brand']=brand
sneakers['Product']=product
sneakers['Discount']=discount
sneakers['Price']=price
sneakers
# Out:
#                   Brand                                            Product  \
# 0             DUNKASTON                                   Sneakers For Men
# 1                BRUTON      Modern Trendy Sneakers Shoes Sneakers For Men
# 2   World Wear Footwear                                   Sneakers For Men
# 3            HIGHLANDER                                   Sneakers For Men
# 4                Chevit  Super Stylish & Trendy Combo Pack of 02 Pairs ...
# ..                  ...                                                ...
# 95           HIGHLANDER  494 Perfect Sports Shoes for Running Training ...
# 96                 aadi                                   Sneakers For Men
# 97              Bretton  Stylish Comfortable Lightweight, Breathable Ca...
# 98              Numenzo                                   Sneakers For Men
# 99           HIGHLANDER                    casual for men Sneakers For Men
#
#    Discount Price
# 0   77% off  ₹343
# 1   80% off  ₹259
# ...

# %% [markdown]
# # Question 7

# %%
driver=webdriver.Chrome('Chromedriver.exe')
driver.get('https://www.myntra.com/shoes')
driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[6]/ul/li[1]/label').click()

# %%
driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label/div').click()

# %%
brand=[]
description=[]
price=[]
for b in driver.find_elements_by_xpath('//h3[@class="product-brand"]'):
    brand.append(b.text)
for d in driver.find_elements_by_xpath('//h4[@class="product-product"]'):
    description.append(d.text)
for p in driver.find_elements_by_xpath('//div[@class="product-price"]'):
    price.append(p.text)

# %%
driver.find_element_by_xpath('/html/body/div[2]/div/div[1]/main/div[3]/div[2]/div/div[2]/section/div[2]/ul/li[12]').click()

# %%
brand_=[]
description_=[]
price_=[]
for b in driver.find_elements_by_xpath('//h3[@class="product-brand"]'):
    brand_.append(b.text)
for d in driver.find_elements_by_xpath('//h4[@class="product-product"]'):
    description_.append(d.text)
for p in driver.find_elements_by_xpath('//div[@class="product-price"]'):
    price_.append(p.text)

# %%
brand.extend(brand_)
description.extend(description_)
price.extend(price_)

# %%
shoes=pd.DataFrame({})
shoes['Brand']=brand
shoes['Description']=description
shoes['Price']=price
shoes
# Out:
#              Brand                              Description  \
# 0             ALDO                Men Leather Driving Shoes
# 1           Reebok             Men Zig Dynamica 2.0 Running
# 2             Nike               Men Winflo 7 Running Shoes
# 3             ALDO                     Men Printed Sneakers
# 4   Tommy Hilfiger             Men Cleated Leather Sneakers
# ..             ...                                      ...
# 95         Saint G              Women High-Top Heeled Boots
# 96         Saint G  Leather Block Heeled Boots with Buckles
# 97         Saint G               Embellished Flatform Boots
# 98  ROSSO BRUNELLO              High-Top Block Heeled Boots
# 99        DAVINCHI      Men Textured Formal Leather Loafers
#
#                           Price
# 0                     Rs. 12999
# 1                      Rs. 7999
# 2                      Rs. 7995
# 3    Rs. 9099Rs. 12999(30% OFF)
# 4     Rs. 7739Rs. 8599(10% OFF)
# ..                          ...
# ...

# %% [markdown]
# # Question 8

# %%
driver=webdriver.Chrome('Chromedriver.exe')
driver.get('https://www.amazon.in/')
driver.find_element_by_xpath('/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input').send_keys('laptop')
driver.find_element_by_xpath('/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input').click()

# %%
driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[4]/li[13]/span/a/div/label/i').click()

# %%
title=[]
rating=[]
price=[]
for t in driver.find_elements_by_xpath('//span[@class="a-size-medium a-color-base a-text-normal"]'):
    title.append(t.text)
for r in driver.find_elements_by_xpath('//span[@class="a-size-base s-underline-text"]'):
    rating.append(r.text)
for p in driver.find_elements_by_xpath('//span[@class="a-price-whole"]'):
    price.append(p.text)

# %%
Title=title[0:10]
Rating=rating[0:10]
Price=price[0:10]

# %%
laptop=pd.DataFrame({})
laptop['Title']=Title
laptop['Rating']=Rating
laptop['Price']=Price
laptop
# Out:
#                                                Title Rating     Price
# 0  ASUS VivoBook 14 (2021), 14-inch (35.56 cms) F...     23    57,490
# 1  ASUS TUF Gaming F15 (2021), 15.6" (39.62 cms) ...      3    89,990
# 2  ASUS VivoBook 14 (2021), 14-inch (35.56 cms) F...     23    57,490
# 3  ASUS TUF Gaming F15 (2021), 15.6" (39.62 cms) ...      3    89,990
# 4  Mi Notebook Ultra 3.2K Resolution Display Inte...    916    77,499
# 5  Lenovo ThinkBook 15 Intel 11th Gen Core i7 15....     32    90,990
# 6  HP Pavilion x360 11th Gen Intel Core i7 14 inc...     77    85,790
# 7  LG Gram 14 Intel Evo 11th Gen Core i7 14 inche...     85    88,990
# 8  Acer Predator Helios 300 11th Gen Intel Core i...      2  1,69,990
# 9  LG Gram Intel Evo 11th Gen Core i7 17 inches U...    140    96,999

# %% [markdown]
# # Question 9

# %%
driver=webdriver.Chrome('Chromedriver.exe')
driver.get('https://www.ambitionbox.com/')

# %%
driver.find_element_by_xpath('/html/body/div[1]/nav/nav/a[6]').click()

# %%
driver.find_element_by_xpath('/html/body/div/div/div/div[2]/div[1]/div/div/div/div/span/input').send_keys('Data Scientist')

# %%
driver.find_element_by_xpath('/html/body/div/div/div/div[2]/div[1]/div/div/div/button/span').click()

# %%
driver.find_element_by_xpath('/html/body/div/div/div/div[2]/div[2]/div[1]/div/div/div/div[2]/div[1]/i').click()

# %%
driver.find_element_by_xpath('/html/body/div/div/div/div[2]/div[2]/div[1]/div/div/div/div[2]/div[2]/div/div[2]/input').send_keys('Noida')

# %%
driver.find_element_by_xpath('/html/body/div/div/div/div[2]/div[2]/div[1]/div/div/div/div[2]/div[2]/div/div[3]/div[1]/div[1]/div/label').click()

# %%
company=[]
days=[]
rating=[]
for c in driver.find_elements_by_xpath('//p[@class="company body-medium"]'):
    company.append(c.text)
for d in driver.find_elements_by_xpath('//span[@class="body-small-l"]'):
    days.append(d.text)
for r in driver.find_elements_by_xpath('//span[@class="body-small"]'):
    rating.append(r.text)

# %%
day=days[0:20:2]
day

# %%
driver=webdriver.Chrome('Chromedriver.exe')
driver.get('https://www.ambitionbox.com/')

# %%
job=pd.DataFrame({})
job['Company name']=company
job['job post date']=day
job['rating']=rating
job

# %% [markdown]
# # Question 10

# %%
driver.find_element_by_xpath('/html/body/div[1]/nav/nav/a[4]').click()

# %%
driver.find_element_by_xpath('/html/body/div/div/div/main/section[1]/div[2]/div[1]/span/input').send_keys('Data Scientist')

# %%
driver.find_element_by_xpath('/html/body/div/div/div/main/section[1]/div[2]/div[1]/span/div/div/div[1]/div/div/p').click()

# %%
company=[]
tsalary=[]
asalary=[]
misalary=[]
exprience=[]
for c in driver.find_elements_by_xpath('//div[@class="name"]'):
    company.append(c.text)
for t in driver.find_elements_by_xpath('//div[@class="name"]'):
    tsalary.append(t.text)
for a in driver.find_elements_by_xpath('//p[@class="averageCtc"]'):
    asalary.append(a.text)
for mi in driver.find_elements_by_xpath('//div[@class="value body-medium"]'):
    misalary.append(mi.text)
for ex in driver.find_elements_by_xpath('//div[@class="salaries sbold-list-header"]'):
    exprience.append(ex.text)

# %%
mins=misalary[0:20:2]
mins
# Out:
# ['₹ 15.0L',
#  '₹ 9.5L',
#  '₹ 11.0L',
#  '₹ 9.5L',
#  '₹ 8.3L',
#  '₹ 8.3L',
#  '₹ 10.0L',
#  '₹ 8.5L',
#  '₹ 5.8L',
#  '₹ 6.9L']

# %%
maxs=misalary[1:20:2]
maxs
# Out:
# ['₹ 25.5L',
#  '₹ 20.0L',
#  '₹ 21.3L',
#  '₹ 22.0L',
#  '₹ 20.0L',
#  '₹ 20.5L',
#  '₹ 21.0L',
#  '₹ 15.0L',
#  '₹ 24.0L',
#  '₹ 23.4L']

# %%
salary=pd.DataFrame({})
salary['Company and salary record']=company
salary['average salary']=asalary
salary['max salary']=maxs
salary['min salary']=mins
salary
# Out:
#                         Company and salary record average salary max salary  \
# 0                  Ab Inbev\nbased on 28 salaries        ₹ 20.3L    ₹ 25.5L
# 1                        ZS\nbased on 15 salaries        ₹ 15.3L    ₹ 20.0L
# 2                     Optum\nbased on 25 salaries        ₹ 15.1L    ₹ 21.3L
# 3         Fractal Analytics\nbased on 77 salaries        ₹ 15.1L    ₹ 22.0L
# 4           Tiger Analytics\nbased on 33 salaries        ₹ 14.4L    ₹ 20.0L
# 5              UnitedHealth\nbased on 52 salaries        ₹ 13.9L    ₹ 20.5L
# 6                   Verizon\nbased on 14 salaries        ₹ 12.7L    ₹ 21.0L
# 7  Ganit Business Solutions\nbased on 13 salaries        ₹ 12.4L    ₹ 15.0L
# 8                  Ericsson\nbased on 43 salaries        ₹ 11.9L    ₹ 24.0L
# 9                  Deloitte\nbased on 57 salaries        ₹ 11.7L    ₹ 23.4L
#
#   min salary
# 0    ₹ 15.0L
# 1     ₹ 9.5L
# 2    ₹ 11.0L
# 3     ₹ 9.5L
# 4     ₹ 8.3L
# 5     ₹ 8.3L
# 6    ₹ 10.0L
# 7     ₹ 8.5L
# ...
